# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('SampleSuperstore.csv')

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   int8
#  1   Segment       9994 non-null   int8
#  2   Country       9994 non-null   int8
#  3   City          9994 non-null   int16
#  4   State         9994 non-null   int8
#  5   Postal Code   9994 non-null   int16
#  6   Region        9994 non-null   int8
#  7   Category      9994 non-null   int8
#  8   Sub-Category  9994 non-null   int8
#  9   Sales         9994 non-null   int16
#  10  Quantity      9994 non-null   int8
#  11  Discount      9994 non-null   int8
#  12  Profit        9994 non-null   int16
# dtypes: int16(4), int8(9)
# memory usage: 166.0 KB

# %%
df.describe()
# Out:
#          Ship Mode      Segment  Country         City        State  \
# count  9994.000000  9994.000000   9994.0  9994.000000  9994.000000
# mean      2.235041     0.658995      0.0   279.957274    22.343206
# std       1.100880     0.762622      0.0   139.157896    15.504611
# min       0.000000     0.000000      0.0     0.000000     0.000000
# 25%       2.000000     0.000000      0.0   164.000000     4.000000
# 50%       3.000000     0.000000      0.0   295.000000    27.000000
# 75%       3.000000     1.000000      0.0   394.000000    36.000000
# max       3.000000     2.000000      0.0   530.000000    48.000000
#
#        Postal Code       Region     Category  Sub-Category        Sales  \
# count  9994.000000  9994.000000  9994.000000   9994.000000  9994.000000
# mean    312.058835     1.570642     0.972584      7.590454  2575.845908
# std     200.197633     1.162329     0.629544      5.051429  1647.651858
# min       0.000000     0.000000     0.000000      0.000000     0.000000
# 25%     101.000000     1.000000     1.000000      3.000000  1114.000000
# 50%     312.500000     1.000000     1.000000      9.000000  2388.500000
# 75%     515.000000     3.000000     1.000000     12.000000  3953.000000
# max     630.000000     3.000000     2.000000     16.000000  5824.000000
#
#           Quantity     Discount       Profit
# count  9994.000000  9994.000000  9994.000000
# mean      2.789574     2.278867  3659.327096
# std       2.225110     2.951928  1993.873504
# min       0.000000     0.000000     0.000000
# 25%       1.000000     0.000000  2043.250000
# 50%       2.000000     3.000000  3621.500000
# 75%       4.000000     3.000000  5320.000000
# max      13.000000    11.000000  7286.000000

# %%
df = df.apply(lambda x: pd.Categorical(x).codes)
df.head()
# Out:
#    Ship Mode  Segment  Country  City  State  Postal Code  Region  Category  \
# 0          2        0        0   194     15          217       2         0
# 1          2        0        0   194     15          217       2         0
# 2          2        1        0   266      3          517       3         1
# 3          3        0        0   153      8          170       2         0
# 4          3        0        0   153      8          170       2         1
#
#    Sub-Category  Sales  Quantity  Discount  Profit
# 0             4   4205         1         0    5740
# 1             5   5219         2         0    6962
# 2            10    969         1         0    3301
# 3            16   5392         4         7      75
# 4            14   1360         1         3    2257

# %%
x=df.drop('Profit',axis=1)
x
# Out:
#       Ship Mode  Segment  Country  City  State  Postal Code  Region  Category  \
# 0             2        0        0   194     15          217       2         0
# 1             2        0        0   194     15          217       2         0
# 2             2        1        0   266      3          517       3         1
# 3             3        0        0   153      8          170       2         0
# 4             3        0        0   153      8          170       2         1
# ...         ...      ...      ...   ...    ...          ...     ...       ...
# 9989          2        0        0   295      8          169       2         0
# 9990          3        0        0   104      3          555       3         0
# 9991          3        0        0   104      3          555       3         2
# 9992          3        0        0   104      3          555       3         1
# 9993          2        0        0   517      3          560       3         1
#
#       Sub-Category  Sales  Quantity  Discount
# 0                4   4205         1         0
# 1                5   5219         2         0
# 2               10    969         1         0
# 3               16   5392         4         7
# 4               14   1360         1         3
# ...            ...    ...       ...       ...
# 9989             9   1482         2         3
# 9990             9   3029         1         0
# 9991            13   4193         1         3
# 9992            12   1644         3         0
# 9993             1   4120         1         0
#
# [9994 rows x 12 columns]

# %%
y=df['Profit']
y
# Out:
# 0       5740
# 1       6962
# 2       3301
# 3         75
# 4       2257
#         ...
# 9989    2684
# 9990    4467
# 9991    4766
# 9992    4244
# 9993    6270
# Name: Profit, Length: 9994, dtype: int16

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (7995, 12)

# %%
y_train.shape
# Out:
# (7995,)

# %%
x_test.shape
# Out:
# (7995,)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(x_test)
x_pred=reg.predict(x_train)

# %%
from sklearn.metrics import r2_score ,  mean_absolute_error
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.553435559134319
# 1024.550592552812
